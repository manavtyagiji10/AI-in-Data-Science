# %% [markdown]
# <a href="https://colab.research.google.com/github/manavtyagiji10/AI-in-Data-Science/blob/main/matplotlib%26seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib.lines import lineStyles
Sales={"Months":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],
"Sales_unit":[20,21,22,23,24,25,26,35,34,34,36,38],
"Revenue_in_lakh":[3,5,6,7,8,9,12,15,16,18,22,25]}

import matplotlib.pyplot as plt
import pandas as pd
plt.plot(Sales["Months"],Sales["Revenue_in_lakh"],marker="o")
plt.xlabel("Months",color="green",fontsize="18")
plt.ylabel("Sales_unit",color="green",fontsize="18")
plt.legend(["Revenue_in_lakh"])
plt.grid(True)
plt.show()

# %%
plt.bar(Sales['Months'],Sales['Revenue_in_lakh'],color="red")
plt.show()

# %%
plt.hist(Sales['Revenue_in_lakh'],color="green")
plt.xlabel("Revenue_in_lakh")
plt.ylabel("Frequency")
plt.legend(["Revenue_in_lakh"])
plt.grid(True)
plt.show()

# %%
q1=sum(Sales["Revenue_in_lakh"][0:3])
q2=sum(Sales["Revenue_in_lakh"][3:6])
q3=sum(Sales["Revenue_in_lakh"][6:9])
q4=sum(Sales["Revenue_in_lakh"][9:12])
plt.pie([q1,q2,q3,q4],labels=["Q1","Q2","Q3","Q4"],autopct="%1.2f%%",explode=(0,0,0.1,0))
plt.title("Quarterly Revenue")
plt.legend(["Q1","Q2","Q3","Q4"])
plt.show()

# %%
plt.scatter(Sales["Months"],Sales["Sales_unit"],color="red",marker="s")
plt.xlabel("Months")
plt.ylabel("Sales_unit")
plt.legend(["Sales_unit"])
plt.grid(True)
plt.show()

# %% [markdown]
# Data vizulization with Seborn- For big data

# %%
#libiraris
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-84801637-3d4b-4eda-b957-60f9925cbc27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84801637-3d4b-4eda-b957-60f9925cbc27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex",palette="prism",markers=["s","o"],style="sex",dashes=False,legend="full")
sns.set_theme(style="ticks")
plt.show()

# %%
sns.displot(df['bill_length_mm'],bins=[10,20,30,40,50,60],kde=True,rug=True)
plt.show()

# %%
sns.displot(data=df,x="bill_length_mm",bins=[10,20,30,40,50,60],hue="sex",rug=True,kde=True)
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue="sex")
plt.show()

# %%
sns.barplot(x="species",y="bill_length_mm",data=df)
plt.show()

# %%
sns.boxenplot(x="species",y="body_mass_g",data=df)
plt.show()

# %%
sns.violinplot(x="species",y="body_mass_g",data=df,color="rgb",hue="sex",palette="magma")
sns.set_theme(style="ticks")
plt.show()
#

# %%
sns.heatmap(df.select_dtypes('number').corr(),annot=True)
plt.show()

# %%
sns.pairplot(df,hue="species")
plt.show()

# %%
sns.jointplot(x="bill_length_mm",y="bill_depth_mm",data=df,kind="kde")
plt.show()

# %%
sns.kdeplot(data=df,x="bill_length_mm",y="bill_depth_mm",hue="species")
plt.show()

# %%
sns.regplot(x="bill_length_mm",y="bill_length_mm",data=df)
plt.show()
